# %% [markdown]
# <a href="https://colab.research.google.com/github/BillWorstell/PyTomography/blob/main/t_siminddata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# See https://pytomography.readthedocs.io/en/latest/usage.html
#
# Modified to run from Google Colab:
# https://colab.research.google.com/
#
# Data stored on Google Drive in
# path = '/content/drive/MyDrive/pytomography_tutorial_data/simind_tutorial/'
#
# May require restart after first run
#
# Tested with V100 GPU on Colab

# %%
# !pip install fastapi
# !pip install kaleido
# !pip install monai
# !pip install uvicorn
# !pip install python-multipart
# !pip install pytomography
# Out:
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (0.104.1)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi) (3.7.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi) (1.10.13)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi) (0.27.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from fastapi) (4.8.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi) (1.2.0)
# Requirement already satisfied: kaleido in /usr/local/lib/python3.10/dist-packages (0.2.1)
# Requirement already satisfied: monai in /usr/local/lib/python3.10/dist-packages (1.3.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from monai) (1.26.2)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from monai) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (4.8.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9->monai) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9->monai) (1.3.0)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.10/dist-packages (0.24.0.post1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: typing-extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (4.8.0)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (0.0.6)
# Requirement already satisfied: pytomography in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: fft-conv-pytorch>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pytomography) (1.2.0)
# Requirement already satisfied: kornia>=0.6.12 in /usr/local/lib/python3.10/dist-packages (from pytomography) (0.7.0)
# Requirement already satisfied: matplotlib>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from pytomography) (3.8.2)
# Requirement already satisfied: numpy>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from pytomography) (1.26.2)
# Requirement already satisfied: pydicom>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pytomography) (2.4.3)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from pytomography) (1.11.4)
# Requirement already satisfied: torch>=1.10.2 in /usr/local/lib/python3.10/dist-packages (from pytomography) (2.1.0+cu118)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kornia>=0.6.12->pytomography) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->pytomography) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->pytomography) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->pytomography) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->pytomography) (1.4.5)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->pytomography) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->pytomography) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->pytomography) (2.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.2->pytomography) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.2->pytomography) (4.8.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.2->pytomography) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.2->pytomography) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.2->pytomography) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.2->pytomography) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.2->pytomography) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8.0->pytomography) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.2->pytomography) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.2->pytomography) (1.3.0)

# %% [markdown]
# Reconstructing SIMIND Data

# %%
import os
from pytomography.io.SPECT import simind
from pytomography.projectors import SPECTSystemMatrix
from pytomography.transforms import SPECTAttenuationTransform, SPECTPSFTransform
from pytomography.algorithms import OSEM
from pytomography.transforms import GaussianFilter
from torch import poisson
import matplotlib.pyplot as plt

# %% [markdown]
# Set the folder location for downloaded files (you will need to modify this to be the directory where you saved the files)

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/pytomography_tutorial_data/simind_tutorial/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Check directories for files

# %%
# !ls -ltr /content/drive/MyDrive/pytomography_tutorial_data/simind_tutorial/
# !ls -ltr /content/drive/MyDrive/pytomography_tutorial_data/simind_tutorial/multi_projections
# Out:
# total 12
# drwx------  2 root root 4096 Dec  5 20:17 phantom_organs
# drwx------  2 root root 4096 Dec  5 21:54 single_projections
# drwx------ 14 root root 4096 Dec  5 22:26 multi_projections
# total 24626
# -rw------- 1 root root 25165824 Dec  5 21:15 mu208.ict
# -rw------- 1 root root     1312 Dec  5 21:15 mu208.hct
# drwx------ 2 root root     4096 Dec  5 22:26 salivary
# drwx------ 2 root root     4096 Dec  5 22:26 r_lung
# drwx------ 2 root root     4096 Dec  5 22:26 r_kidney_medulla
# drwx------ 2 root root     4096 Dec  5 22:26 r_kidney_cortex
# drwx------ 2 root root     4096 Dec  5 22:26 r_kidney
# drwx------ 2 root root     4096 Dec  5 22:26 l_lung
# drwx------ 2 root root     4096 Dec  5 22:26 l_kidney_medulla
# drwx------ 2 root root     4096 Dec  5 22:26 l_kidney_cortex
# drwx------ 2 root root     4096 Dec  5 22:26 l_kidney
# drwx------ 2 root root     4096 Dec  5 22:26 liver
# drwx------ 2 root root     4096 Dec  5 22:26 bladder
# drwx------ 2 root root     4096 Dec  5 22:26 bkg

# %% [markdown]
# Case 1: Single Projection File
# When running SIMIND simulations, it is commonly the case that organs, background, and lesions are simulated seperately and then added together in projection space after the fact. For now, lets consider the liver region, and how it would look to simulate/reconstruct a scan consisting only of a liver.

# %%
photopeak_path = os.path.join(path, 'multi_projections', 'liver', 'photopeak.h00')
upperscatter_path = os.path.join(path, 'multi_projections', 'liver', 'lowerscatter.h00')
lowerscatter_path = os.path.join(path, 'multi_projections', 'liver', 'upperscatter.h00')
attenuation_path = os.path.join(path, 'single_projections', 'body1.hct')

# %% [markdown]
# Open required metadata for reconstruction

# %%
object_meta, proj_meta = simind.get_metadata(photopeak_path)

# %%
# !ls -ltr /content/drive/MyDrive/pytomography_tutorial_data/simind_tutorial/multi_projections/liver
# Out:
# total 92170
# -rw------- 1 root root     2211 Dec  5 22:26 photopeak.h00
# -rw------- 1 root root     2217 Dec  5 22:26 lowerscatter.h00
# -rw------- 1 root root     2207 Dec  5 22:26 primary.h00
# -rw------- 1 root root     2217 Dec  5 22:26 upperscatter.h00
# -rw------- 1 root root 23592960 Dec  5 22:29 lowerscatter.a00
# -rw------- 1 root root 23592960 Dec  5 22:29 photopeak.a00
# -rw------- 1 root root 23592960 Dec  5 22:29 primary.a00
# -rw------- 1 root root 23592960 Dec  5 22:29 upperscatter.a00

# %% [markdown]
# Open the projection data corresponding to the photopeak:

# %%
photopeak = simind.get_projections(photopeak_path)

# %% [markdown]
# The data generated in SIMIND has units of counts per second per MBQ. A real SPECT scan has units of counts. The reason SIMIND provides these units is that * it allows one to scale for (i) different net patient activities and (ii) different scanner acquisition times * multiple noise realizations can be obtained. Once counts are obtained using (i) and (ii) above, the “real number” data is used as Poisson mean values, and noise realizations are generated

# %%
activity = 100 # MBq
projection_time = 15 #seconds, typical of Lu177 scan
photopeak = poisson(photopeak * activity * projection_time)

# %% [markdown]
# The projection data consists of a series of 2D images taken at different angles around the imaged object:

# %%
sample_projections = photopeak[0,::15].cpu().numpy()
sample_angles = proj_meta.angles[::15]
fig, axes = plt.subplots(1,8,figsize=(8,2.5))
for i, ax in enumerate(axes):
    ax.pcolormesh(sample_projections[i].T, cmap='magma')
    ax.set_title(f'{sample_angles[i]:.0f}'+r'$^{\circ}$')
    ax.axis('off')
fig.tight_layout()

# %% [markdown]
# Open the estimate for the scatter using the get_scatter_from_TEW method:

# %%
scatter = simind.get_scatter_from_TEW(
    headerfile_peak = photopeak_path,
    headerfile_lower = lowerscatter_path,
    headerfile_upper = upperscatter_path
)
scatter = poisson(scatter * activity * projection_time)

# %% [markdown]
# The following transform is used for attenuation correction in the system matrix. It uses a 3D attenuation map generated via SIMIND

# %%
attenuation_map = simind.get_attenuation_map(attenuation_path)
att_transform = SPECTAttenuationTransform(attenuation_map)

# %% [markdown]
# The following allows for PSF modeling in the system matrix:

# %%
psf_meta = simind.get_psfmeta_from_header(os.path.join(path, 'single_projections', 'body1t2ew6_tot_w2.hdr'))
psf_transform = SPECTPSFTransform(psf_meta)

# %% [markdown]
# Now we can build our system matrix
# . Both the attenuation transform and PSF transform are fed to the obj2obj_transforms argument, with the attenuation transform coming first:

# %%
system_matrix = SPECTSystemMatrix(
    obj2obj_transforms = [att_transform,psf_transform],
    proj2proj_transforms = [],
    object_meta = object_meta,
    proj_meta = proj_meta,
    n_parallel=2)

# %% [markdown]
# The system matrix is then used to create the reconstruction algorithm, which in this case is OSEM:

# %%
reconstruction_algorithm = OSEM(
    projections = photopeak,
    system_matrix = system_matrix,
    scatter = scatter)

# %% [markdown]
# Get the reconstructed object

# %%
reconstructed_object = reconstruction_algorithm(n_iters=10, n_subsets=8)

# %% [markdown]
# PyTomography also has functionality for Gaussian post-smoothing. In this case, we’ll apply post smoothing with a 1cm FWHM.

# %%
post_smoothing_filter = GaussianFilter(1)
post_smoothing_filter.configure(object_meta,proj_meta)
reconstructed_object_filt = post_smoothing_filter(reconstructed_object)

# %% [markdown]
# Plot the reconstructed object next to the CT. * The reconstructed object has units of counts, and would need to be adjusted by a proportionality factor if one wants to obtain units of MBq

# %%
plt.subplots(1,2,figsize=(8,6))
plt.subplot(121)
plt.pcolormesh(reconstructed_object_filt[0].cpu()[:,70].T, cmap='magma')
plt.colorbar()
plt.axis('off')
plt.title('Reconstructed Object')
plt.subplot(122)
plt.pcolormesh(attenuation_map.cpu()[0][:,70].T, cmap='Greys_r')
plt.colorbar()
plt.axis('off')
plt.title('$\mu$ (CT scan)')
plt.show()

# %% [markdown]
# Case 2: Multiple Regions
# When running simulations with SIMIND, it is standard to run different regions of the body seperately and then combine them together in projection space after the fact. This enables one to create arbtrary organ activities using the same set of simulated data. A few noteworthy things
#
# SIMIND projection data is typically given in units of CPS/MBq where CPS=counts/second. Real life SPECT data consists of units of counts. In order to simulate a realistic scenario, therefore, we need to multiply the projections by some value in MBq, and some value in seconds. The value in MBq corresponds to the total activity of the organ/region you’ve simulated. The value in seconds corresponds to the total projection time.
#
# We’ll start by opening up SIMIND projections corresponding to 8 distinct regions of the body, each with activities representative of a true clinical case

# %%
organs = ['bkg', 'liver', 'l_lung', 'r_lung', 'l_kidney', 'r_kidney','salivary', 'bladder']
activities = [2500, 450, 7, 7, 100, 100, 20, 90] # MBq
headerfiles = [os.path.join(path, 'multi_projections', organ, 'photopeak.h00') for organ in organs]
headerfiles_lower = [os.path.join(path, 'multi_projections', organ, 'lowerscatter.h00') for organ in organs]
headerfiles_upper = [os.path.join(path, 'multi_projections', organ, 'upperscatter.h00') for organ in organs]

# %% [markdown]
# Open the projection/scatter data

# %%
object_meta, proj_meta = simind.get_metadata(headerfiles[0]) #assumes the same for all
photopeak = simind.combine_projection_data(headerfiles, activities)
scatter = simind.combine_scatter_data_TEW(headerfiles, headerfiles_lower, headerfiles_upper, activities)

# %% [markdown]
# Note that our weights were in units of MBq, so our projection data currently has units of counts/second.

# %%
fig, ax = plt.subplots(1, 2, figsize=(6,6))
plt.subplot(121)
im = plt.pcolormesh(photopeak[0,0].cpu().T, cmap='magma')
plt.axis('off')
plt.subplot(122)
plt.pcolormesh(scatter[0,0].cpu().T, cmap='magma')
plt.axis('off')
fig.colorbar(im, ax=ax, location='right', label='Counts/Second', extend='max')

# %% [markdown]
# Now we need to decide how long the scan was taken for. We’ll assume each projection was taken for 15 seconds

# %%
dT = 15 #s
photopeak *= dT
scatter *= dT

# %%
fig, ax = plt.subplots(1, 2, figsize=(6,6))
plt.subplot(121)
im = plt.pcolormesh(photopeak[0,0].cpu().T, cmap='magma')
plt.axis('off')
plt.subplot(122)
plt.pcolormesh(scatter[0,0].cpu().T, cmap='magma')
plt.axis('off')
fig.colorbar(im, ax=ax, location='right', label='Counts', extend='max')

# %% [markdown]
# In realtity, SPECT projection data is noisy. Provided enough events are ran during the SIMIND simulation, the SIMIND data is essentially noise-free. We need to add Poisson noise if we are to simulate a realistic clinical imaging scenario

# %%
photopeak_poisson = poisson(photopeak)
scatter_poisson = poisson(scatter)

# %% [markdown]
# Now can look at our realistic noisy data:

# %%
fig, ax = plt.subplots(1, 2, figsize=(6,6))
plt.subplot(121)
im = plt.pcolormesh(photopeak_poisson[0,0].cpu().T, cmap='magma')
plt.axis('off')
plt.subplot(122)
plt.pcolormesh(scatter_poisson[0,0].cpu().T, cmap='magma')
plt.axis('off')
fig.colorbar(im, ax=ax, location='right', label='Counts', extend='max')

# %% [markdown]
# Now the projection and scatter data is representative of a realistic clinical scenario. Now we reconstruct as we did earlier.

# %%
attenuation_map = simind.get_attenuation_map(os.path.join(path, 'multi_projections', 'mu208.hct'))
att_transform = SPECTAttenuationTransform(attenuation_map)
psf_meta = simind.get_psfmeta_from_header(headerfiles[0])
psf_transform = SPECTPSFTransform(psf_meta)
system_matrix = SPECTSystemMatrix(
    obj2obj_transforms = [att_transform,psf_transform],
    proj2proj_transforms = [],
    object_meta = object_meta,
    proj_meta = proj_meta)
reconstruction_algorithm = OSEM(
    projections = photopeak_poisson,
    system_matrix = system_matrix,
    scatter = scatter_poisson)

# %% [markdown]
# Now we reconstruct:

# %%
reconstructed_object = reconstruction_algorithm(n_iters=10, n_subsets=8)

# %% [markdown]
# Lets see the reconstructed object

# %%
plt.subplots(1,2,figsize=(6,6))
plt.subplot(121)
plt.pcolormesh(reconstructed_object[0].cpu()[:,70].T, cmap='magma')
plt.colorbar()
plt.axis('off')
plt.title('Reconstructed Object')
plt.subplot(122)
plt.pcolormesh(attenuation_map.cpu()[0][:,70].T, cmap='Greys_r')
plt.colorbar()
plt.axis('off')
plt.title('$\mu$ (CT scan)')
plt.show()
